# %%
#conditional statement
a = 26
b = 34
if b > a :
  print("b is greater than a")
#1. If condition statement
age = 20
if age >19:
  print("you are an adult")

a = 250
b = 103
if b > a :
  print("b is greater than a")

#input + if condition

age = int(input("enter your age : "))
if age > 19 :
  print("you are an adult")

#If else' conditional statement
temp = 30
if temp > 25 :
  print("it's a hot day")
else :
  print("it's a cool day")

#input + if - else condition
age = int(input("Enter your name : "))
if age > 19 :
  print("you are an adult")
else :
  print("you are not adult")

#3. if - elif - else conditional statement
# let's write a code to classify the student's grade based on their total marks (out of 100)
score = 85
if score > 90 :
  print("grade - A")
elif score > 80 :
  print("grade - B")
elif score >  70 :
  print("grade - c")
else :
  print("grade - d")
#let's write a code to classify the student's grade based on their total marks (out of 100)
#input + if - elif - else
marks = int (input("Enter your marks - 100 :"))
if marks >= 90 :
  print("grade A+")
elif marks >= 80 :
  print("grade A")
elif marks >= 70 :
  print("grade B")
else :
  print("grade c poor")
#Nested If-else
number = 7
if number >0 :
  if number % 2 ==0 :
    print("the number is positive and even.")
  else :
    print("the number is possitive and odd.")
else :
  if number == 0 :
    print("the number is zero.")
  else :
    print("the number is negative.")
# student result & grading system using nested if-else
marks = int(input("Enter your marks"))
if marks >=33 :
  print("you are pass")
  if marks >=75 :
    print("graade A")
  else :
     if marks >= 60:
       print("grade b")
     else:
       print("grade c")
else :
  print("you are fail")
# student result & grading system using nested if-else
mr = int(input("enter your marks"))
if mr >=40 :
  print("you are pass")
  if mr >=90 :
    print("grade a+ ")
  else :
     if mr > 80 :
        print("grade a ")
     else :
      if mr >=60 :
       print("grade b ")
      else :
       print("grade c ")
else :
    print("fail")

# conditional expression (ternary operators)
age = int(input("Enter your age :"))
status = "adult" if age >18 else "minore"
print(status)
# Out:
# Enter your age :34
# adult
